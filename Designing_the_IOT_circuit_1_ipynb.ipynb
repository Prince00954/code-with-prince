# %% [markdown]
# <a href="https://colab.research.google.com/github/Prince00954/code-with-prince/blob/main/Designing_the_IOT_circuit_1_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# // C++ code for blinking two LEDs int led1 = 12; int led2 = 11;
#
# void setup() { pinMode(led1, OUTPUT); pinMode(led2, OUTPUT); }
#
# void loop() { digitalWrite(led1, HIGH); delay(400); // LED 1 ON digitalWrite(led1, LOW);
#
# digitalWrite(led2, HIGH); delay(400); // LED 2 ON digitalWrite(led2, LOW); }

# %%
from IPython.display import Image
(Image("image1.png", width=400))
